# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rml_df = pd.read_csv('./data/rml_df.csv')

# %%
rml_df[rml_df['patient_id'] == 1339]
# Out:
#        patient_id  stage_start_time  stage_end_time  stage_duration  \
# 45570        1339               0.0           300.0           300.0
# 45571        1339               0.0           300.0           300.0
# 45572        1339               0.0           300.0           300.0
# 45573        1339               0.0           300.0           300.0
# 45574        1339             300.0           600.0           300.0
# ...           ...               ...             ...             ...
# 45656        1339            3900.0          4200.0           300.0
# 45657        1339            3900.0          4200.0           300.0
# 45658        1339            3900.0          4200.0           300.0
# 45659        1339            4200.0          4500.0           300.0
# 45660        1339            4500.0          4530.0            30.0
#
#       stage_type  event_start_time  event_end_time  event_duration  \
# 45570    NonREM1             191.5           201.5            10.0
# ...
