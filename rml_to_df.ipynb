# %%
import xml.etree.ElementTree as ET
from utils import *

# %%
rml_folder_path = './data/rml/'

rml_file_path = './data/rml/00000995-100507.rml'

# %%
rml_df_converter(rml_file_path).get_matched_df()
# Out:
#     patient_id  stage_start_time  stage_end_time  stage_duration stage_type  \
# 0          995               0.0           210.0           210.0       Wake
# 1          995             210.0           300.0            90.0    NonREM1
# 2          995             300.0           870.0           570.0    NonREM2
# 3          995             870.0           930.0            60.0       Wake
# 4          995             930.0           960.0            30.0    NonREM1
# ..         ...               ...             ...             ...        ...
# 244        995           17400.0         17700.0           300.0        REM
# 245        995           17700.0         17730.0            30.0       Wake
# 246        995           17730.0         17760.0            30.0    NonREM1
# 247        995           17760.0         17880.0           120.0    NonREM2
# 248        995           17760.0         17880.0           120.0    NonREM2
#
# ...

# %%
rml_df = rml_to_concat_df(rml_folder_path).get_concat_df()
# Out:
# Converting...00001535-100507.rml
# Converting...00001502-100507.rml
# Converting...00001374-100507.rml
# Converting...00001557-100507.rml
# Converting...00001202-100507.rml
# Converting...00001609-100507.rml
# Converting...00001316-100507.rml
# Converting...00001474-100507.rml
# Converting...00001677-100507.rml
# Converting...00001640-100507.rml
# Converting...00001122-100507.rml
# Converting...00001615-100507.rml
# Converting...00001701-100507.rml
# Converting...00001386-100507.rml
# Converting...00001699-100507.rml
# Converting...00001292-100507.rml
# Converting...00001486-100507.rml
# Converting...00001045-100507.rml
# Converting...00001151-100507.rml
# Converting...00001604-100507.rml
# Converting...00001010-100507.rml
# Converting...00001651-100507.rml
# Converting...00001104-100507.rml
# Converting...00001618-100507.rml
# Converting...00001571-100507.rml
# Converting...00001224-100507.rml
# Converting...00001059-100507.rml
# Converting...00001118-100507.rml
# ...

# %%
rml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75596 entries, 0 to 75595
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   patient_id        75596 non-null  object
#  1   stage_start_time  75596 non-null  float64
#  2   stage_end_time    75596 non-null  float64
#  3   stage_duration    75596 non-null  float64
#  4   stage_type        75596 non-null  object
#  5   event_start_time  75596 non-null  object
#  6   event_end_time    75596 non-null  object
#  7   event_duration    75596 non-null  object
#  8   respiratory_type  75596 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 5.2+ MB

# %%
rml_df.to_csv('./data/rml_df.csv', index=False)
