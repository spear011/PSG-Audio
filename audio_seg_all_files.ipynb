# %%
import pandas as pd
import os
import numpy as np
import glob

import soundfile as sf

from utils import *

# %%
data_path = 'E:/REM Detection/psg_audio_dataset/sleep_stage_audio_data/wav/'
sr = 48000

save_path = 'E:/REM Detection/psg_audio_dataset/input_audio_data/sliced_wav/'

# %%
sliced_wav_file_list = make_sliced_wav(data_path, save_path, 20, 10).segment_wav_file()
# Out:
# Getting patient id list completed. 286 patients found.
# Segmenting patient 00000995...
# Saving sliced wav files to E:/REM Detection/psg_audio_dataset/input_audio_data/sliced_wav/00000995...
# Patient 00000995 completed.
# Remaining 285 patients.
# Segmenting patient 00000999...
# Saving sliced wav files to E:/REM Detection/psg_audio_dataset/input_audio_data/sliced_wav/00000999...
# Patient 00000999 completed.
# Remaining 284 patients.
# Segmenting patient 00001000...
# Saving sliced wav files to E:/REM Detection/psg_audio_dataset/input_audio_data/sliced_wav/00001000...
# Patient 00001000 completed.
# Remaining 283 patients.
# Segmenting patient 00001006...
# Saving sliced wav files to E:/REM Detection/psg_audio_dataset/input_audio_data/sliced_wav/00001006...
# Patient 00001006 completed.
# Remaining 282 patients.
# Segmenting patient 00001008...
# Saving sliced wav files to E:/REM Detection/psg_audio_dataset/input_audio_data/sliced_wav/00001008...
# Patient 00001008 completed.
# ...

# %%
wav_df = pd.DataFrame(sliced_wav_file_list)

# %%
sliced_wav_file_list[0]
# Out:
# 'E:/REM Detection/psg_audio_dataset/input_audio_data/sliced_wav/00001701/00001701_01_00_000.wav'

# %%
wav_df.to_csv('E:/REM Detection/psg_audio_dataset/input_audio_data/sliced_wav_file_list.csv', index=False)

# %%
wav_df[0]
# Out:
# 0       E:/REM Detection/psg_audio_dataset/input_audio...
# 1       E:/REM Detection/psg_audio_dataset/input_audio...
# 2       E:/REM Detection/psg_audio_dataset/input_audio...
# 3       E:/REM Detection/psg_audio_dataset/input_audio...
# 4       E:/REM Detection/psg_audio_dataset/input_audio...
#                               ...
# 1882    E:/REM Detection/psg_audio_dataset/input_audio...
# 1883    E:/REM Detection/psg_audio_dataset/input_audio...
# 1884    E:/REM Detection/psg_audio_dataset/input_audio...
# 1885    E:/REM Detection/psg_audio_dataset/input_audio...
# 1886    E:/REM Detection/psg_audio_dataset/input_audio...
# Name: 0, Length: 1887, dtype: object
