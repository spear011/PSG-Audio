# %%
import xml.etree.ElementTree as ET
from utils import *

# %%
rml_folder_path = './data/psg_audio/rml_clean/'

rml_file_path = './data/psg_audio/rml_clean/00000995-100507.rml'

# %%
rml_df_converter(rml_file_path).get_matched_df()
# Out:
#     patient_id  stage_start_time  stage_end_time  stage_duration stage_type  \
# 0          995               0.0           210.0           210.0       Wake
# 1          995             210.0           300.0            90.0    NonREM1
# 2          995             300.0           870.0           570.0    NonREM2
# 3          995             870.0           930.0            60.0       Wake
# 4          995             930.0           960.0            30.0    NonREM1
# ..         ...               ...             ...             ...        ...
# 234        995           17400.0         17700.0           300.0        REM
# 235        995           17700.0         17730.0            30.0       Wake
# 236        995           17730.0         17760.0            30.0    NonREM1
# 237        995           17760.0         17880.0           120.0    NonREM2
# 238        995           17760.0         17880.0           120.0    NonREM2
#
# ...

# %%
rml_to_concat_df(rml_folder_path).get_concat_df()
# Out:
# Converting...00000995-100507.rml
# Converting...00000999-100507.rml
# Converting...00001000-100507.rml
# Converting...00001006-100507.rml
#     patient_id  stage_start_time  stage_end_time  stage_duration stage_type  \
# 0          995               0.0           210.0           210.0       Wake
# 1          995             210.0           300.0            90.0    NonREM1
# 2          995             300.0           870.0           570.0    NonREM2
# 3          995             870.0           930.0            60.0       Wake
# 4          995             930.0           960.0            30.0    NonREM1
# ..         ...               ...             ...             ...        ...
# 850       1006           13890.0         14190.0           300.0    NonREM2
# 851       1006           13890.0         14190.0           300.0    NonREM2
# 852       1006           13890.0         14190.0           300.0    NonREM2
# ...
